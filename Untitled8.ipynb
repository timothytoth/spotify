# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
from imblearn.over_sampling import SMOTE

# %%
# Read- in my personal listening histroy in which I obtainted through Spotify
df = pd.read_csv(r"C:\Users\Tim\OneDrive\Desktop\streaming_history")

# %%
# Read- in Song Features dataset
features = pd.read_csv(r"C:\Users\Tim\OneDrive\Desktop\audio_features")

# %%
df.head()
# Out:
#    Unnamed: 0           endTime    artistName  \
# 0           0  2022-03-06 16:44        MARION
# 1           1  2022-04-04 20:36         mike.
# 2           2  2022-04-05 15:51  Deep October
# 3           3  2022-04-05 15:52         Drake
# 4           4  2022-04-05 15:56  One True God
#
#                           trackName  msPlayed
# 0                         Afterlife    128234
# 1                        These Days    145388
# 2                   God in the Room    193006
# 3  Wants and Needs (feat. Lil Baby)     55875
# 4                          Addicted    245258

# %%
# Dropping irrelevant columns 
df = df.drop('Unnamed: 0', axis=1)
# Renaming the column names
df = df.rename(columns={"artistName":"artist","endTime":"date","trackName":"track"})

# %%
df.head(20)
# Out:
#                 date              artist  \
# 0   2022-03-06 16:44              MARION
# 1   2022-04-04 20:36               mike.
# 2   2022-04-05 15:51        Deep October
# 3   2022-04-05 15:52               Drake
# 4   2022-04-05 15:56        One True God
# 5   2022-04-05 16:00          Juice WRLD
# 6   2022-04-05 16:03               bbno$
# 7   2022-04-05 22:02        Deep October
# 8   2022-04-05 22:05        Deep October
# 9   2022-04-05 22:09           Lil Wayne
# 10  2022-04-05 22:09       THAT DUDE DAX
# 11  2022-04-05 22:12           21 Savage
# 12  2022-04-05 22:14           SAINt JHN
# 13  2022-04-05 22:16       THAT DUDE DAX
# 14  2022-04-05 22:19       THAT DUDE DAX
# 15  2022-04-06 03:23            A$AP ANT
# 16  2022-04-06 03:23       THAT DUDE DAX
# 17  2022-04-06 03:26           21 Savage
# 18  2022-04-06 03:29       THAT DUDE DAX
# 19  2022-04-06 03:32  The Adicctive Boyz
#
#                                                 track  msPlayed
# ...

# %%
df.shape
# Out:
# (18998, 4)

# %%
# Group the DataFrame by 'artist', 'track', and 'msPlayed', and then count the number of occurrences
df['listen_count'] = df.groupby(['track'])['date'].transform('count')

# %%
df.shape
# Out:
# (18998, 5)

# %%
df.head(50)
# Out:
#                 date                                             artist  \
# 0   2022-03-06 16:44                                             MARION
# 1   2022-04-04 20:36                                              mike.
# 2   2022-04-05 15:51                                       Deep October
# 3   2022-04-05 15:52                                              Drake
# 4   2022-04-05 15:56                                       One True God
# 5   2022-04-05 16:00                                         Juice WRLD
# 6   2022-04-05 16:03                                              bbno$
# 7   2022-04-05 22:02                                       Deep October
# 8   2022-04-05 22:05                                       Deep October
# 9   2022-04-05 22:09                                          Lil Wayne
# 10  2022-04-05 22:09                                      THAT DUDE DAX
# 11  2022-04-05 22:12                                          21 Savage
# ...

# %%
# Group the DataFrame by 'artist', 'track', and 'msPlayed', and then sum the 'listen_count' for each group
df['total_count'] = df.groupby(['track'])['listen_count'].transform('sum')

# Drop duplicate rows to keep unique songs
df = df.drop_duplicates(subset='track')

# %%
df.head(50)
# Out:
#                 date                                             artist  \
# 0   2022-03-06 16:44                                             MARION
# 1   2022-04-04 20:36                                              mike.
# 2   2022-04-05 15:51                                       Deep October
# 3   2022-04-05 15:52                                              Drake
# 4   2022-04-05 15:56                                       One True God
# 5   2022-04-05 16:00                                         Juice WRLD
# 6   2022-04-05 16:03                                              bbno$
# 9   2022-04-05 22:09                                          Lil Wayne
# 10  2022-04-05 22:09                                      THAT DUDE DAX
# 11  2022-04-05 22:12                                          21 Savage
# 12  2022-04-05 22:14                                          SAINt JHN
# 15  2022-04-06 03:23                                           A$AP ANT
# ...

# %%
df.shape
# Out:
# (3144, 6)

# %%
features_2 = features.drop(columns=['track_id', 'Unnamed: 0'])

# %%
features_2.head()
# Out:
#   artist_name                                      track_name  acousticness  \
# 0          YG  Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj      0.005820
# 1          YG                    BAND DRUM (feat. A$AP Rocky)      0.024400
# 2       R3HAB                                   Radio Silence      0.025000
# 3  Chris Cooq                                         Lactose      0.029400
# 4  Chris Cooq                             Same - Original mix      0.000035
#
#    danceability  duration_ms  energy  instrumentalness  key  liveness  \
# 0         0.743       238373   0.339             0.000    1    0.0812
# 1         0.846       214800   0.557             0.000    8    0.2860
# 2         0.603       138913   0.723             0.000    9    0.0824
# 3         0.800       125381   0.579             0.912    5    0.0994
# 4         0.783       124016   0.792             0.878    7    0.0332
#
#    loudness  mode  speechiness    tempo  time_signature  valence  popularity
# ...

# %%
merged_df = df.merge(features_2, left_on='track', right_on='track_name', how='inner')

merged_df.shape
# Out:
# (7711, 22)

# %%
merged_data.head(50)
# Out:
#                 date        artist       track  msPlayed  listen_count  \
# 0   2022-03-06 16:44        MARION   Afterlife    128234             7
# 1   2022-03-06 16:44        MARION   Afterlife    128234             7
# 2   2022-03-06 16:44        MARION   Afterlife    128234             7
# 3   2022-03-06 16:44        MARION   Afterlife    128234             7
# 4   2022-03-06 16:44        MARION   Afterlife    128234             7
# 5   2022-03-06 16:44        MARION   Afterlife    128234             7
# 6   2022-03-06 16:44        MARION   Afterlife    128234             7
# 7   2022-04-04 20:36         mike.  These Days    145388             1
# 8   2022-04-04 20:36         mike.  These Days    145388             1
# 9   2022-04-04 20:36         mike.  These Days    145388             1
# 10  2022-04-04 20:36         mike.  These Days    145388             1
# 11  2022-04-04 20:36         mike.  These Days    145388             1
# ...

# %%
features.shape
# Out:
# (247035, 18)
